# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import xlwings as xw
import matplotlib.pyplot as plt

# %% [markdown]
# ### Define global variables

# %%
sheetNames = ['p', 'ey', 'fcfy', 'eps', 'ptbv', 'dy', 'mv']
fileName = '\DissData_V01.xlsx'
relativeLocation = r"..\data" + fileName
absoluteLocation = r"C:\Users\rfg\OneDrive\Desktop\Dissertation ES30029\data" + fileName
companyNames = ['Price', 'ABACUS GROUP PLC.', 'ABBEY NATIONAL PLC.', 'ABBOT GROUP PLC.', 'ABBOTT MEAD VICKERS PLC.', 'ABERDEEN ASSET MAN.PLC.', 'ABERFORTH SMCOS.IT.PLC.', 'ABDN.NEW DAWN IT.PLC.', 'DISCOVERIE GROUP PLC.', 'PURA PLC.', 'ACORN GP.PLC.', 'ADMIRAL PLC.', 'ADSCENE GROUP PLC.', 'ADWEST AUTOMOTIVE PLC.', 'AEGIS GROUP PLC.', 'AIRSPRUNG GROUP PLC.', 'THOMAS COOK GROUP PLC.', 'HARVARD INTL.PLC.', 'ALBERT FISHER PLC', 'ALBRIGHT & WILSON PLC.', 'ALEXANDRA PLC.', 'ALLDERS PLC.', 'SPEEDY HIRE PLC.', 'ALLIANCE TRUST PLC.', 'ALLIED COLLOIDS GP.PLC.', 'ALLIED DOMECQ PLC.', 'ALLIED TEXTILE COS.PLC.', 'ALPHA AIRPORTS GP.PLC.', 'ALUMASC GROUP PLC.', 'ALVIS PLC.', 'AMEC FOSTER WHEELER PLC.', 'NORTH AMER.INC.TST.PLC', 'AMERSHAM PLC.', 'BRITANNIC SMCOS.TST.PLC.', 'AMSTRAD PLC.', 'AMLIN PLC.', 'ANGLIAN GROUP PLC.', 'AWG PLC.', 'ANGLO & OVERSEAS PLC.', 'API GROUP PLC.', 'APPLEYARD GROUP PLC.', 'APPLIED DS.GROUP PLC.', 'APV PLC.', 'ARCADIAN INTL.PLC.', 'ARGENT GROUP PLC', 'ARGOS PLC.', 'SAFEWAY PLC. (UK)', 'ARJO WIGGINS APL.PLC.', 'ASCOT PLC', 'ASDA GROUP PLC.', 'ASDA PROPERTY HDG.PLC.', 'ASH & LACY PLC.', 'ASHBOURNE PLC.', 'ASHLEY(LAURA) HDG.PLC.', 'ASHTEAD GROUP PLC.', 'ASSOCIATED BRIT.FDS.PLC.', 'ASSD.BRIT.PORTS HDG.PLC.', 'ASW HOLDINGS PLC.', 'ATLAS CONVERTING EQU.', 'AUSTIN REED GROUP PLC.', 'AUTV.PRECN.HDG.PLC.', 'AVON RUBBER PLC.', 'AZLAN GROUP PLC.', 'BRITISH AMER.TOB.PLC.', 'BRITAX INTERNATIONAL PLC', 'BAA PLC.', 'ABDN.DIVR.I&G.TST.PLC', 'BLLE.GIFF.JAPAN SMCOS.', 'BAIRD (WILLIAM) PLC.', 'GTL RESOURCES PLC.', 'BANK OF SCOTLAND', 'BANKERS IT.PLC.', 'BARCLAYS PLC.', 'AGGREGATE INDS.PLC.', 'TRIBUNE TRUST PLC.', 'BARR (AG) PLC.', 'BARRATT DEVS.PLC.', 'SIX CONTINENTS PLC.', 'BAYNES CHARLES', 'BBA AVIATION PLC.', 'BEATTIE (JAMES) PLC.', 'BEAZER GROUP PLC', 'BELLWAY PLC.', '4IMPRINT GROUP PLC.', 'BRIT IN.HDG.N V PLC.', 'ENODIS PLC.', 'BERKELEY GROUP HDG.PLC.', 'CONSORT MEDICAL PLC.', 'BET PLC.', 'BETA GLB.EMRG.MKTS.PLC.', 'BETTERWARE PLC.', 'BI GROUP', 'BALFOUR BEATTY PLC.', 'BILTON PLC.', 'BIOCOMPATIBLES INTL.PLC.', 'BIRKBY', 'BLACK (PETER) HDG.PLC.', 'BLAGDEN PLC', 'BLENHEIM GROUP PLC.', 'BLICK PLC.', 'BLUE CIRCLE INDS.PLC.NEW', 'BLUEBIRD TOYS PLC.', 'BOC GROUP PLC.', 'BODY SHOP INTL.PLC.', 'BODYCOTE PLC.', 'BOOKER PLC.', 'BOOSEY & HAWKES PLC.', 'BOOT (HENRY) PLC.', 'ALLIANCE BOOTS PLC.', 'BOSTROM PLC.', 'SPIRENT COMMS.PLC.', 'BOXMORE INTL.PLC.', 'BPB PLC.', 'BPP HOLDINGS PLC.', 'BPT PLC.', 'BRADSTOCK GROUP PLC.', 'BRAKE BROTHERS PLC.', 'BRAMMER PLC.', 'BRENT INTL.PLC.', 'BRIDON PLC.', 'BSTL.UNITED PRESS PLC.', 'BRISTOL WATER GROUP PLC.', 'RESOLUTION PLC.', 'BAE SYSTEMS PLC.', 'BRITISH AIRWAYS PLC.', 'VERNALIS PLC.', 'AVI GLOBAL TRUST PLC.', 'BG GROUP PLC.', 'BRITISH LAND CO.PLC.', 'BP PLC.', 'BRIT.POLYTHENE INDS.PLC.', 'SKY PLC.', 'CORUS GROUP PLC.', 'BT GROUP PLC.', 'BRITISH VITA PLC.', 'BRIT-BORNEO OIL&GAS PLC.', 'BRITTON GP.PLC.', 'BRIXTON PLC.', 'BROWN GROUP PLC.', 'COATS GROUP PLC.', 'BRUNNER INV.TST.PLC.', 'BRYANT GROUP PLC.', 'BSS GROUP PLC.', 'BTG LTD.', 'BTP PLC.', 'BTR PLC.', 'BUDGENS PLC.', 'BULLOUGH PLC.', 'BULMER (HP) HDG.PLC.', 'BUNZL PLC.', 'BURFORD HDG.PLC.', 'BURMAH CASTROL PLC.', 'BURN STEW.DISTS.PLC.', 'ARCADIA GROUP PLC', 'UK MAIL GROUP PLC.', 'BWI PLC.', 'BZW CONVERTIBLE IT.PLC.', 'CABLE & WRLS.COMMS.PLC.', 'CADBURY PLC.', 'CAIRN ENERGY PLC.', 'CALEDONIA INVS.PLC.', 'CALOR GROUP PLC.', 'CAMAS PLC.', 'CANDOVER INVS.PLC.', 'CANNING (W) PLC.', 'CAPITA PLC.', 'CAPITAL & REGIONAL PLC.', 'CAPITAL CORP.PLC.', 'CAPITAL INDS.PLC.', 'GCAP MEDIA PLC.', 'NAVAN MINING PLC.', 'CARCLO PLC.', 'CARLTON COMMS.PLC.', 'CARPETRIGHT PLC.', 'CASTINGS PLC.', 'CATER ALLEN HDG.PLC.', 'CATTLES PLC.', 'CAVAGHAN & GRAY GP.PLC.', 'CELLTECH GROUP PLC.', 'CELSIS INTL.PLC.', 'CHARTER INTL.PLC.', 'CHELSFIELD PLC.', 'CHEMRING GROUP PLC.', 'CHESTERFIELD PR.PLC.', 'CHIROSCIENCE GP.PLC.', 'CHLORIDE GROUP PLC.', 'CHRISTIES INTL.PLC.', 'CHRYSALIS PLC.', 'DIVISION GP.PLC.', 'TEMPUS GROUP PLC', 'RESTAURANT GROUP PLC.', 'CLAREMONT GARM.', 'CLM IN.FUND PLC', 'CLOSE BROTHERS GP.PLC.', 'CLS HOLDINGS PLC.', 'CLYDE PETROLEUM', 'CLYDEPORT PLC', 'CMG PLC', 'COATS PLC.', 'COBHAM PLC.', 'CODA GROUP', 'COLLEAGUES GROUP', 'AVIVA PLC.', 'CMTY. HOSPITALS GP. PLC', 'COMPASS GROUP PLC.', 'CONCENTRIC PLC.', 'COOK (WILLIAM) PLC.', 'VESUVIUS PLC.', 'CORDIANT COMMS.GP.PLC.', 'CORPORATE SVS.GP.PLC.', 'CORTWORTH PLC.', 'COUNTRYSIDE PROPS.PLC.', 'COURT CVNDSH.GP.PLC.', 'COURTAULDS PLC.', 'COURTAULDS TEXT.PLC.', 'COURTS PLC.', 'ARRIVA PLC.', 'COX IN.HOLDINGS PLC.', 'CRABTREE GROUP PLC.', 'ANITE PLC.', 'CREST NICHOLSON PLC.', 'CRITCHLEY GP.PLC.', 'CRODA INTERNATIONAL PLC.', 'SPRING GROUP PLC.', 'DAEJAN HOLDINGS PLC.', 'DLY.ML.& GEN.TST.PLC.', 'SYGEN INTERNATIONAL PLC.', 'DANKA BUSINES SYS.PLC.', 'DARTMOOR INV.TST.PLC.', 'DATRONTECH GP.PLC.', 'DAVID BROWN GP.PLC.', 'BERENDSEN LTD.', 'DAWSON INTL.PLC.', 'DAWSON', 'DE LA RUE ORD.', 'DELPHI GP.PLC.', 'DELTA PLC.', 'DENBY GROUP PLC.', 'DERWENT LONDON PLC.', 'U AND I GROUP PLC.', 'DEVRO PLC.', 'DEWHIRST GROUP PLC.', 'DFS FURNITURE CO.PLC.', 'DIPLOMA PLC.', 'DIXONS RETAIL PLC.', 'DOMESTIC & GEN.GP.PLC.', 'DOMINO PRINT.SCIS.PLC.', 'DOMNICK HUNTER GP.PLC.', 'DORLING KINDER.HDG.PLC.', 'DOWDING & MILLS PLC.', 'DRUCK HOLDINGS PLC', 'DUNEDIN INC.GW.IT.PLC.', 'DUNEDIN SMCOS.IT.PLC.', 'DUNEDIN WWD.IT.PLC.', 'ET.MIDLANDS ELTY.PLC.', 'EDINBURGH DGN.TST.PLC.', 'EDINBURGH INV.TRUST PLC.', 'EDIN.NEW TIGER IT.PLC.', 'STD.LF.UK SMCOS.TST.PLC.', 'EIS GP.', 'ELECTRA PRIVATE EQ.PLC.', 'ELECTRIC & GEN.IT.PLC.', 'ELECTROCOMP.PLC.', 'ELLIS & EVERARD PLC.', 'EMAP PLC.', 'HENDERSON GLB.TST.PLC.', 'ENG.CHINA CLAYS PLC.', 'EI GROUP PLC.', 'ENTERPRISE OIL PLC.', 'EPWIN GROUP PLC.', 'ETAM PLC.', 'HOLIDAYBREAK PLC.', 'EURODIS ELECTRON PLC.', 'EUROPEAN MOTOR HDG.PLC.', 'EUROTHERM PLC.', 'EUROTUNNEL PLC.', 'EVANS HALSHAW HDG.PLC.', 'EVANS OF LEEDS PLC.', 'INTERCAPITAL PLC.', 'EXPAMET INTL.PLC.', 'EXPRO INTL.GP.PLC.', 'FABER PREST PLC.', 'SPECTRIS PLC.', 'PREMIER FARNELL PLC.', 'FENCHURCH PLC.', 'FENNER PLC.', 'FERGUSON INTL.HDG.PLC.', 'FID.EUR.VALUES IT.PLC.', 'FIDELITY JAPAN TRUST PLC', 'FIELD GROUP PLC.', 'FII GROUP PLC.', 'FILOFAX GROUP PLC.', 'FILTRONIC PLC.', 'STUDIO RETAIL GROUP PLC.', 'FINELIST GROUP PLC.', 'FINLAY (JAMES) PLC.', 'FINS.GW.& INC.TST.PLC', 'TUI TRAVEL PLC.', 'FIRST LEISURE CORP.PLC.', 'FIRST TECHNOLOGY PLC.', 'FIRST GROUP PLC.', 'FIRTH RIXSON PLC.', 'FKI PLC.', 'JPMORGAN AMERICAN IT.PLC', 'JPMORGAN CLAVERHOUSE PLC', 'JPMORGAN EUROPEAN IT.PLC', 'JPMORGAN EMRG.MKTS.PLC', 'JPMORGAN MID CAP IT.PLC', 'JPMORGAN EUR.SMCOS.PLC.', 'FLEM.FAR EASTERN IT.PLC.', 'JPMORGAN US SMCOS.PLC', 'JPMORGAN INDIAN IT.PLC.', 'JPMORGAN JAPANESE PLC.', 'MERCANTILE IT.PLC.', 'JPMORGAN GLB.G&I.PLC', 'FLEXTECH PLC.', 'F&C EMERGING MKTS.PLC.', 'ICG ENTERPRISE TRUST PLC', 'F&C IT.PLC.', 'F&C GERMAN PLC.', 'WITAN PACIFIC IT.PLC.', 'THE EUROPEAN IT.PLC.', 'BMO CAP.&.INC.IT.PLC.', 'BMO GLB.SMCOS.PLC.', 'JUPITER US SMCOS.PLC.', 'F&C INCOME GW.IT.PLC.', 'FORTH PORTS PLC.', 'FORTUNE OIL PLC.', 'FORWARD GP.', 'FROGMORE ESTATES PLC.', 'SAVE GROUP PLC.', 'FULLER SMITH &TURNR PLC.', 'GT JAPAN INV.TST.PLC.', 'GAMES WORKSHOP GP.PLC.', 'GART.EMRG.PAC.IT.PLC.', 'GARTMORE', 'GEEST PLC.', 'GENERAL ACCID.PLC.', 'GENERAL CABLE PLC.', 'GENERAL ELECTRIC CO.', 'GERRARD GROUP PLC', 'THE GGT GROUP', 'GIBBS MEW PLC.', 'GKN PLC.', 'GLAXOSMITHKLINE PLC.', 'MJ GLEESON PLC.', 'AGA RANGEMASTER GP.PLC.', 'GO-AHEAD GROUP PLC.', 'GOLDSBOROUGH HLTHCR.PLC.', 'NORTHGATE PLC.', 'GOVETT ORIENTAL IT.PLC.', 'GOVETT STRATEGIC IT.PLC.', 'GRAHAM GROUP PLC.', 'GRAINGER PLC.', 'MALCOLM GROUP PLC.', 'GRAMPIAN TV.PLC.', 'ITV PLC.', 'GRAND MET.PLC.', 'GRASEBY PLC.', 'GREAT PORTLAND ESTS.PLC.', 'HOME RETAIL GROUP PLC.', 'GREENALLS GP.', 'GREENE KING PLC.', 'HENDERSON INV.CO. PLC.', 'GREGGS PLC.', 'GREYCOAT PLC.', 'GUARDIAN RYL.EX.PLC.', 'DIAGEO PLC.', 'GWR GROUP PLC.', 'HTV GROUP PLC.', 'INFAST GROUP PLC.', 'HALL ENGN.(HDG.)PLC.', 'HALMA PLC.', 'JAMES HALSTEAD PLC.', 'HAMBROS PLC.', 'HAMLEYS PLC.', 'HAMMERSON PLC.', 'HANSON PLC.', 'HARDY OIL & GAS PLC.', 'HARDYS & HANSONS PLC.', 'ELEMENTIS PLC.', 'HAVELOCK EUROPA PLC.', 'HAYS PLC.', 'HAZLEWOOD FOODS PLC.', 'HCG LLOYDS IT.PLC.', 'HEADLAM GROUP PLC.', 'HEALTHCALL GP.PLC.', 'HEATH (CE)PLC.', 'HELICAL REIT PLC.', 'HENDERSON', 'HENDERSON OPPS.IT.PLC.', 'HENLYS GROUP PLC.', 'HEPWORTH PLC.', 'HERALD INVESTMENT PLC.', 'HEWDEN-STUART PLC.', 'HEYWOOD WILLIAMS GP.PLC.', 'HICKING PENTCST.PLC.', 'HICKSON INTL.PLC.', 'SWAN HILL GP.PLC.', 'HIGHLAND DISTILLERS PLC.', 'HILL & SMITH HDG.PLC.', 'HILLSDOWN HDG.PLC.', 'EDIN.UK SMCOS.TRKR.PLC', 'HODDER HEADLINE PLC.', 'HOGG ROBINSON GROUP PLC.', 'HOLLIDAY CHM.HDG.PLC.', 'HOLT (JOSEPH)PLC.', 'HOUSE OF FRASER PLC.', 'HOWDEN GROUP PLC.', 'HOZELOCK GROUP PLC.', 'HSBC HOLDINGS PLC.', 'HEND.JAPAN SMCOS.IT.PLC.', 'HUNTING PLC.', 'HTGDN.LF.SCIS.GP.PLC.', 'HUNTLEIGH TECH.PLC.', 'IBC GROUP PLC.', 'IBSTOCK PLC.', 'BIG FOOD GROUP PLC.', 'INTERX PLC', 'IMI PLC.', 'IMPERIAL CHM.INDS.PLC.', 'INCHCAPE PLC.', 'INDE.INSURANCE GP.PLC.', 'INSPEC PLC.', 'INTERMEDIATE CAP.GP.PLC.', 'INVERESK PLC.', 'INVESCO ASIA TRUST PLC.', 'INVESCO ENG.& INTL.PLC.', 'INVESCO LTD.', 'INVESCO TOKYO TRUST PLC.', 'INVESTORS CAP.IT.PLC.', 'ISA INTL.PLC.', 'F&C ASSET MAN.PLC.', 'JARVIS PORTER GROUP PLC.', 'JBA HOLDINGS PLC.', 'JIB GROUP PLC.', 'JJB SPORTS PLC.', 'JKX OIL & GAS PLC.', 'JOHNSON SERVICE GP.PLC.', 'JOHNSON MATTHEY PLC.', 'JOHNSTON PRESS PLC.', 'JONES STROUD (HLDG.)PLC.', 'KALON GROUP PLC.', 'KELLER GROUP PLC.', 'KENWOOD APP. PLC.', 'KINGFISHER PLC.', 'CHARTER EUROPEAN PLC.', 'KLEIN.EUR.PVTN.IT.PLC.', 'KLEIN.OVERSEAS IT.PLC.', 'KWIK SAVE GP.PLC.', 'KWIK-FIT HDG.PLC.', 'LADBROKES CORAL GP.PLC.', 'LAING JOHN PLC.', 'LAIRD PLC.', 'LAMONT HDG.PLC.', 'LAND SECURITIES GP.PLC.', 'LAPORTE', 'ENI LASMO PLC.', 'THE LAW DEB.CORP PLC.', 'LERMTH.&BUR.MSS.PLC.', 'LEEDS GROUP PLC.', 'LEGAL & GENERAL GP.PLC.', 'LEIGH INTERESTS PLC.', 'RAC PLC.', 'LIBERTY PLC.', 'LIFE SCIENCES INT.PLC.', 'LINTON PARK PLC.', 'LITHO SUPPLIES PLC.', 'JARDINE LLOYD THMP.PLC.', 'LLOYDS CHEMISTS PLC.', 'LLOYDS BANKING GP.PLC.', 'LOGICA PLC.', 'LDN.&MANC.GP.', 'LDN.& ST.LAWR.INV.PLC.', 'LDN.AMERICAN GW.TST.PLC.', 'LONDON CLUBS INTL.PLC.', 'LONDON ELTY.PLC.', 'LDN.FORFAITING PLC.', 'LIMIT PLC', 'LONDON INTL.GP.PLC.', 'LONDON MER.SECS.PLC.', 'LONDON SCOT.BANK PLC.', 'LONMIN PLC.', 'LOW & BONAR PLC.', 'LOWLAND INV.CO.PLC.', 'LAMBERT FENCHURCH GP.PLC', 'LUCAS INDUSTRIES', 'LYNX GP.PLC.', 'M&G GROUP (HDG.) PLC.', 'SLG REALISATIONS PLC.', 'SEDGEMOOR 745499', 'INNOVATA PLC.', 'M Y HOLDINGS PLC.', 'MACALLAN-GLVT.PLC.', 'GLENMORANGIE PLC.', 'MACFARLANE GROUP PLC.', 'MACRO 4 PLC.', 'MAI', 'MAJEDIE INVS.PLC.', 'ABERDEEN UK TRACKER PLC', 'MAN GROUP PLC.', 'MANCHESTER UNITED PLC.', 'MANDERS PLC.', 'MANSFIELD BREW.PLC.', 'MARKS & SPENCER GP.PLC.', 'MARLEY PLC.', 'MARLING INDS.PLC.', 'MARSHALLS PLC.', 'MARSTON THMP.&EVERSHED', 'MTCR.AI.UCND.TST. PLC.', 'MATTHEW CLARK PLC.', 'MATTHEWS(BERNARD)PLC.', 'MAUNDERS (JOHN)GP.PLC.', 'MAYBORN GROUP PLC.', 'MAYFLOWER CORP.PLC.', 'MCALPINE(ALFRED)PLC.', 'MCBRIDE PLC.', 'MCCARTHY & STONE PLC.', 'NORTHGATE INFO.SLTN.PLC.', 'MCKECHNIE PLC.', 'MCLEOD RUS.PF.', 'MECONIC PLC.', 'MEDEVA PLC.', 'MEGGITT PLC.', 'PENTEX ENERGY PLC.', 'MENVIER-SWAIN GP.PLC.', 'MENZIES (JOHN) PLC.', 'MEPC PLC.', 'THE MERCHANTS TST.PLC.', 'MERCURY ASSET MAN.', 'MRLY. EUROPEAN PLC.', 'KEYSTONE IT.PLC.', 'BLACKR.WLD.MNG.TST.PLC.', 'MERSEY DOCKS & HRBR.CO.', 'METAL BULLETIN PLC.', 'METALRAX GROUP PLC.', 'MEYER INTL.PLC.', 'HOWDEN JOINERY GP.PLC.', 'MORAN HOLDINGS PLC.', 'APTITUDE SFTW.GP.PLC.', 'MID KENT HDG.PLC.', 'MIDL.INDE.NWSP.PLC.', 'MIDLANDS ELTY.PLC.', 'MIRROR GP.PLC.', 'MISYS PLC.', 'MITIE GROUP PLC.', 'MPAC GROUP PLC.', 'THE MONKS INV.TRUST PLC.', 'MONUMENT OIL&GAS PLC.', 'MARTIN CURRIE SMCOS.PLC.', 'MORE GROUP', 'MORGAN ADVANCED MRA.PLC.', 'ABDN.STD.EITR.PLC.', 'MORLAND & CO.PLC.', 'MORRISON PLC.', 'MORRISON(WM)SPMKTS.PLC.', 'MOSS BROTHERS GROUP PLC.', 'MOWLEM JOHN PLC.', 'MTL INSTRUMENTS GP.PLC.', 'MUCKLOW A&J GROUP PLC.', 'MURRAY INC.TST.PLC.', 'THE HARTSTONE GROUP PLC.', 'MURRAY INTL.TST.PLC.', 'MURRAY VENTURES', 'NATIONAL EXPRESS GP.PLC.', 'NATIONAL GRID (WI)', 'PARAGON GP.OF COS.PLC.', 'INTERNATIONAL POWER PLC.', 'NAT.WSTM.BANK PLC.', 'GART.GROWTH OPT.ORD.PLC', 'NELSON HURST PLC.', 'NESTOR HLTHCR.GP.PLC.', 'NEW LONDON CAP.PLC.', 'NEWMAN TONKS GP.PLC.', 'NEXT PLC.', 'BURNDENE INVS.PLC.', 'NICHOLS PLC.', 'GRESHAM HOUSE STGC.PLC.', 'NORBAIN PLC.', 'NORCROS PLC.', 'NORTHERN ELEC.PLC.', 'NORTHERN FOODS PLC.', 'VIRIDIAN GROUP PLC.', 'NOVARA PLC.', 'NURDIN & PEACOCK PLC.', 'NYNEX CABLECOMMS GP.PLC.', 'OASIS STORES PLC.', 'EXEL PLC.', 'OGC INTL.PLC.', 'OLD MUT.SA.TST.PLC.', 'ON DEMAND INFO.PLC.', 'THE OVERSEAS IT.PLC.', 'OXFORD INSTRUMENTS PLC.', 'OXFORD MOLECULAR GP.PLC.', 'QA PLC.', 'PACIFIC ASSETS TST.PLC.', 'PAGE(MICHAEL)GP.PLC.', 'PANTHEON INT.PLC.', 'PARITY GROUP PLC.', 'PARK GROUP PLC.', 'PARTCO GP.PLC.', 'PZ CUSSON PLC.', 'PEARSON PLC.', 'PEEK PLC.', 'PEEL HOLDINGS PLC.', 'THE PELICAN GROUP PLC.', 'PENDRAGON PLC.', 'PEN.& OR.STM.NAV.CO.', 'PENTLAND GROUP PLC.', 'ACAMBIS PLC.', 'PERKINS FOODS PLC.', 'PERPETUAL PLC.', 'PERSIMMON PLC.', 'GB GROUP PLC.', 'PHOTO-ME INTL.PLC.', 'PILKINGTON PLC.', 'PILLAR PROPERTY PLC.', 'PIZZAEXPRESS PLC.', 'PLYSU PLC.', 'POLYPIPE PLC.', 'PORTMEIRION GROUP PLC.', 'PORTS.SUND.NWSP.PLC.', 'PORVAIR PLC.', 'POWELL DUFFRYN PLC.', 'POWERGEN PLC.', 'POWERSCREEN INTL.PLC.', 'PREMIER OIL PLC.', 'PROLIFIC INCOME PLC.', 'PROTEAN PLC.', 'PROVIDENT FINANCIAL PLC.', 'PROWTING PLC.', 'PRUDENTIAL PLC.', 'PSION PLC.', 'PSIT PLC.', 'QUADRAMATIC', 'QSP GROUP PLC.', 'RACAL ELECTRONICS PLC.', 'RAINFORD GP.PLC.', 'SEAENERGY PLC.', 'RANK GROUP PLC.', 'RATHBONE BROTHERS PLC.', 'CHAPELTHORPE PLC.', 'RECKITT BENCKISER GP.PLC', 'REDLAND', 'REDROW PLC.', 'REED EXECUTIVE PLC.', 'RELX PLC.', 'UNITED ASSURANCE GP. PLC', 'REGENT INNS PLC.', 'RELYON GROUP PLC.', 'RENISHAW PLC.', 'RENOLD PLC.', 'RENTOKIL INITIAL PLC.', 'THOMSON REUTERS PLC.', 'REXAM PLC.', 'RICARDO PLC.', 'RIT CAPITAL PTNS.PLC.', 'HARWORTH GROUP PLC.', 'RM PLC.', 'RMC GROUP PLC.', 'ROBERT WISEMAN DRS.PLC.', 'ROLLS-ROYCE HOLDINGS PLC', 'ROTORK PLC.', 'M P EVANS GROUP PLC.', 'DIALIGHT PLC.', 'ROYAL BK.OF SCTL.GP.PLC.', 'ROYAL DOULTON PLC.', 'ROYAL IN.HDG. PLC.', 'RPC GROUP LTD.', 'RIO TINTO PLC.', 'RUBEROID PLC.', 'RUBICON GP. PLC.', 'RUGBY GROUP PLC. (THE)', 'RUTLAND TRUST PLC.', 'THE SAGE GROUP PLC.', 'SAINSBURY J PLC.', 'SALVESEN(CHRIS.) PLC.', 'C D BRAMALL PLC.', 'SANDERSON GROUP PLC.', 'SARACEN VALUE TST.PLC.', 'SAVILLE GORDON ESTS.PLC.', 'SAVOY HOTEL PLC.', 'SCAPA GROUP PLC.', 'SCHOLL PLC.', 'SCHRODER ASIA PAC.FD.PLC', 'SCHRODER INC.GW.FD.PLC.', 'SCHRODER JAP.GW.FD.PLC.', 'BLLE.GIFF.UK GW.FD.PLC', 'SCHRODERS PLC.', 'SCOTIA HOLDINGS PLC.', 'SCOT.& NEWCASTLE PLC.', 'THE SCOT.AMER.INV.CO.PLC', 'SCOTTISH EASTERN IT.PLC.', 'SSE PLC.', 'THE SCOTTISH INV.TST.PLC', 'SCOT.MET.PR. PLC.', 'SCOT.MORTGAGE IT.PLC.', 'SCOTTISH POWER PLC.', 'SCOTTISH RADIO HDG.PLC.', 'STV GROUP PLC.', 'HENDERSON ALT.STGIS.TST.', 'SEARS PLC.', 'SECOND ALLIANCE TST.PLC.', 'EUROLAND PLUS SMCOS. PLC', 'SECURICOR GP. PLC.', 'SECS.TST.OF SCTL.PLC.', 'SEDGWICK GP.PLC.', 'SEMA PLC.', 'SENIOR PLC.', 'SERCO GROUP PLC.', 'SERVISAIR PLC.', 'SSL INTERNATIONAL PLC.', 'SEVERN TRENT PLC.', 'SHAFTESBURY PLC.', 'INTL.PUBLIC RELATIONS', 'RENEWI PLC.', 'ROYAL DUTCH SHELL PLC.', 'INTIMAS GROUP PLC.', 'SHIRES INCOME PLC.', 'SIDLAW GROUP', 'INVENSYS PLC.', 'SIG PLC.', 'SIGNET JEWELERS LTD.', 'SILENTNIGHT HDG. PLC', 'SIMON GROUP PLC.', 'SINGER & FRIED.GP.PLC.', 'AIREA PLC.', 'SEMARA HOLDINGS PLC', 'SEGRO PLC.', 'GRESHAM TECHS.PLC.', 'SMITH & NEPHEW PLC.', 'WILSHAW PLC.', 'SMITH (DS) PLC.', 'SMITHKLINE BEECHAM PLC.', 'SMITHKLINE BHM.CORP.', 'SMITHS GROUP PLC.', 'HOMESERVE PLC.', 'SOUTH WLS.ELTY.', 'PENNON GROUP PLC.', 'HAMPTON TRUST PLC.', 'SOUTHERN ELEC.PLC.', 'SOUTHERN WATER PLC.', 'SPANDEX PLC.', 'SPIRAX-SARCO ENGR.PLC.', 'SPRING RAM CORP.PLC.', 'ST.ANDREW TRUST PLC.', 'KIN AND CARTA PLC.', 'JAMESS PLACE CAP. PLC.', 'ST MODWEN PROPS.PLC.', 'STAGECOACH GROUP PLC.', 'STAKIS PLC.', 'STD.CHARTERED PLC.', 'STANLEY LEISURE PLC.', 'STAVELEY INDS. PLC', 'STERLING INDS.PLC.', 'MOTHERCARE PLC.', 'STOVES GROUP PLC.', 'STRATAGEM GROUP PLC.', 'STYLO PLC.', 'RSA INSURANCE GROUP PLC.', 'SUTER PLC.', 'T & N PLC.', 'T & S STORES PLC.', 'CARE FIRST GROUP', 'TARMAC PLC.', 'TATE & LYLE PLC.', 'TAYLOR NELSON SOFRES PLC', 'TAYLOR WIMPEY PLC.', 'TBI PLC.', 'TELEGRAPH PLC.', 'ZETEX PLC.', 'TELEWEST COMMS.PLC.', 'TELSPEC PLC.', 'TEMPLE BAR IT.PLC.', 'TMPLTN.EMRG.MKTS.IT.PLC.', 'TESCO PLC.', 'THAMES WATER PLC.', 'EMI GROUP PLC.', 'THORNTON ASIAN EMRG.PLC.', 'THORNTONS PLC.', 'BLACKROCK THROG.TST.PLC.', 'FRAM.INNOV.GW.TST.PLC.', 'TI GROUP PLC.', 'TIBBETT &.BRITTEN GP.PLC', 'TIE RACK PLC.', 'INTERSERVE PLC.', 'TIME PRODUCTS PLC.', 'TLG PLC.', 'TOM COBLEIGH', 'TOMKINS PLC.', 'TOWN CENTRE SECS.PLC.', 'CITY OF LDN.IT.PLC.', 'TR EUROPEAN GW.TST.PLC.', 'HEND.FAR EAST INC.LTD.', 'SCHDR.AN.TOR.INV.CO.PLC', 'TR PROPERTY INV.TST.PLC.', 'HENDERSON SMCOS.IT.PLC.', 'TRADE INDEMNITY', 'KVAERNER PLC.', 'TRAFFICMASTER PLC.', 'TRAFFORD PARK ESTS.PLC.', 'INTU PROPERTIES PLC.', 'TDG LTD.', 'TRANSTEC PLC.', 'TRAVIS PERKINS PLC.', 'TRIFAST PLC.', 'DENNIS GROUP PLC.', 'REACH PLC.', 'TRIPLEX LLOYD PLC.', 'TT ELECTRONICS PLC.', 'TUNSTALL GROUP PLC.', 'UDO HOLDINGS PLC.', 'WIRELESS GROUP PLC', 'SVM UK ACTIVE FUND PLC.', 'ALLIANCE UNICHEM PLC.', 'UNIQ PLC.', 'UNILEVER PLC.', 'UNITECH PLC.', 'UNITED BIS.HDG PLC.', 'UTD.FRIENDLY GP.PLC.', 'UBM PLC.', 'UNITED UTILITIES GP.PLC.', 'UNIVERSAL SALVAGE PLC.', 'UPF GROUP PLC.', 'US SMALLER COS.IT.PLC.', 'INVESCO INC.GW.TST.PLC.', 'VALUE AND INC.TST.PLC.', 'CANNONS GROUP PLC.', 'VARDY (REG) PLC.', 'SWALLOW GROUP PLC.', 'VCI PLC.', 'VENDOME LUXURY GP.PLC.', 'VERO GROUP PLC.', 'VICKERS PLC.', 'IMAGINATION TECHS.GP.PLC', 'VIRTUALITY GROUP PLC.', 'VISION GROUP PLC.', 'VITEC GROUP PLC.', 'VODAFONE GROUP PLC.', 'VOLEX PLC.', 'VT GROUP PLC.', 'WACE GROUP PLC.', 'WADDINGTON PLC.', 'WAGON PLC.', 'WAINHOMES PLC.', 'WALKER GREENBANK PLC.', 'WARDLE STOREYS PLC.', 'WARNER ESTATE HDG.PLC.', 'WASSALL PLC.', 'WAT.CTY.OF LDN.PROPS.PLC', 'WATMOUGHS (HDG.)PLC.', 'ALLDAYS PLC.', 'WATTS BLAKE BEA.&CO.PLC.', 'WEIR GROUP PLC.', 'WELLINGTON HOLDINGS PLC.', 'WELLMAN PLC.', 'HYDER PLC.', 'WEMBLEY PLC.', 'WESSEX WATER PLC.', 'WESTBURY PLC.', 'WSTM.HLTH.CARE HDG.PLC.', 'WETHERSPOON (JD) PLC.', 'WHATMAN PLC.', 'WHITBREAD PLC.', 'WATERDORM PLC.', 'WICKES PLC.', 'CHUBB SECURITY PLC.', 'WILLIS CORROON GP.PLC.', 'WILSON BOWDEN PLC.', 'WILSON CONNOLLY PLC.', 'WIMPEY (GEORGE) PLC.', 'WITAN INV.TRUST PLC.', 'FERGUSON PLC.', 'WOLSTENHLME RNK.PLC.', 'MARSTONS PLC.', 'WPP PLC.', 'WYEVALE GDN.CENTRES PLC.', 'WYNDEHAM PRESS NEW ORD', 'YATES GROUP PLC.', 'YORKS. GROUP PLC.', 'YORKSHIRE ELTY.GP.PLC.', 'KELDA GROUP PLC.', 'TYNE TEES TV', 'SYNTHOMER PLC.', 'ASTRAZENECA PLC.', 'ZOTEFOAMS PLC.', '600 GROUP PLC.', '3I GROUP PLC.', 'ALLD.LDN.PROPS.PLC.', 'HAYNES PUBLISHNG GP.PLC.', 'VICTREX PLC.', 'BAGGERIDGE BRICK PLC.', 'BENTALLS PLC.', 'REBUS GROUP PLC.', 'SINCLAIR (WM.) HDG.PLC.', 'TAY HOMES PLC.', 'LONRHO PLC.', 'MERCURY GROUP PLC.', 'NEXT FIFTEEN COMM.PLC.', 'CONNECT GROUP PLC', 'CALA PLC.', 'HARVEY NICHOLS GROUP PLC', 'MLLM.& CPTH.HTLS.PLC', 'ORANGE PLC.', 'RT GP.PLC.', 'SVG CAPITAL PLC.', 'SKYEPHARMA PLC.', 'ST.JAMESS PLACE PLC.', 'THORN', 'VALUE REALISATION PLC.', 'ALLIED CARPETS', 'ATKINS (WS) PLC.', 'BRITISH ENERGY GP.PLC.', 'DAIRY CREST GROUP LTD.', 'JARVIS HOTELS PLC.', 'LUCASVARITY', 'PACE PLC.', 'SOMERFIELD PLC.', 'SUN LIFE & PRVL.HDG. PLC', 'IMPERIAL BRANDS PLC.', 'GRANTCHESTER HDG. PLC', 'AEA TECHNOLOGY GP.PLC.', 'NSM PLC.', 'PROTHERICS PLC.', 'SECOND LONDON AM.IT.PLC.', 'THISTLE HOTELS PLC.', 'THROGMORTON PF.INC.PLC.', 'ULTRA ELT.HDG.PLC.', 'ALEXON GROUP PLC.', 'ALLIED LEISURE PLC.', 'AMEY PLC.', 'ANDREWS SYKES GROUP PLC.', 'ATLANTIC TELECOM GP.PLC', 'BENCHMARK GROUP PLC.', 'BLACKS LEISURE GP.PLC.', 'BRUNNER MOND', 'CANTAB PHARMS.PLC.', 'CAPE PLC.', 'LEEDS UNITED PLC.', 'CEDAR PLC.', 'CENTURY INNS PLC.', 'CHURCHILL CHINA PLC.', 'CITY TECHNOLOGY HDG. PLC', 'CORNWELL PARK.PLC.', 'DRUID GROUP PLC', 'EDIN.FUND MGRS.GP.PLC.', 'EFT GROUP PLC.', 'EIDOS PLC.', 'XANSA PLC.', 'EUROPEAN HOME RET.PLC.', 'FID.ASIAN VALUES IT.PLC.', 'WORLDWIDE HLTHCR.TST.PLC', 'GOLDSMITHS GROUP', 'HARVEYS FURNISHINGS PLC', 'INDUSTRIAL CNTL.SVS.PLC.', 'JARVIS PLC.', 'JD SPORTS FASHION PLC.', 'KEWILL PLC.', 'KINGSBURY GROUP PLC.', 'LIMELIGHT GROUP PLC', 'LUMINAR GROUP HDG.PLC.', 'MMT COMPUTING PLC.', 'MACDONALD HOTELS PLC.', 'MAIDEN GROUP PLC.', 'MANG.BRONZE HDG.PLC.', 'MENTMORE PLC.', 'MINERVA PLC.', 'MORGAN SINDALL GP.PLC.', 'MSB INTERNATIONAL PLC.', 'NORTHERN LEIS.PLC.', 'PERP.INC.&GW.IT.PLC.', 'ILION GROUP PLC.', 'IXICO PLC.', 'PPL THERAPEUTICS PLC.', 'PRESSAC PLC.', 'QUEENS MOAT HSE.PLC.', 'RANSOMES PLC.', 'REGAL HOTEL GP. PLC', 'HOMESTYLE GROUP PLC.', 'SCHDR.EMRG.CTRY.FD.PLC.', 'ARBUTHNOT BKG.GP.PLC.', 'SELECT APPT.HDG. PLC.', 'SEVERFIELD PLC.', 'SHIRE PLC.', 'SOUTHNEWS PLC.', 'STREAMLINE HOLDINGS', 'TOPS ESTATES PLC.', 'TOTTENHAM HOTSPUR PLC.', 'VERNALIS GROUP PLC.', 'HIWAVE TECHNOLOGIES PLC.', 'VISUAL ACTION HDG.PLC.', 'WARNER HOWARD PLC.', 'WASTE RECYCLING GP.PLC.', 'WF ELECTRICAL PLC', 'WILMINGTON PLC.', 'WYKO PLC.', 'BLACKROCK SMCOS.TST.PLC.', 'CENTRICA PLC.', 'ENERGY GROUP', 'COLT GROUP SA', 'EAST SURREY HDG.PLC.', 'NA', 'NOVAR PLC.', 'ALLIANCE & LEICS.PLC.', 'AVIS EUROPE PLC.', 'GALLAHER GP.SPN.ADR 1:4', 'HBOS PLC.', 'LEARNING TECHNOLOGY PLC.', 'AGGREKO PLC.', 'BHP GROUP PLC.', 'JPMORGAN ASIAN PLC.', 'WARNER CHILCOTT PLC.', 'HISCOX DI LTD.', 'IONICA', 'NORWICH UNION PLC.', 'WOOLWICH PLC', 'CREATIVE PUBLISHING', 'UTV', 'BOVIS HOMES GROUP PLC.', 'NEWSQUEST', 'NORTHERN ROCK PLC.', 'SAATCHI & SAATCHI PLC', 'AMER.PORT SERVICES PLC.', 'ASHTENNE HOLDINGS PLC.', 'ASTON VILLA PLC.', 'CAMBRIDGE ATBY.TECH.GP.', 'CIRQUAL', 'COMPEL GROUP PLC.', 'COSTAIN GROUP PLC.', 'DBS MANAGEMENT PLC.', 'DEBENHAMS PLC.', 'DIAGONAL PLC.', 'DIXON MOTORS PLC.', 'EDGE PROPERTIES PLC.', 'ENIC PLC.', 'EUROPEAN TELECOM PLC.', 'HEND.EUR.FOCUS TST.PLC', 'HAMPSON INDUSTRIES PLC.', 'HARVEY NASH GROUP PLC.', 'HENDERSON HIGH INC. NEW', 'POLAR CAP.TECH.TST.PLC.', 'HOLMES PLACE PLC', 'BIDCORP PLC.', 'KBC ADVANCED TECHS.PLC.', 'KIER GROUP PLC.', 'LAVENDON GROUP PLC.', 'LONDON BDG.SFTW.HDG.PLC.', 'LORIEN PLC.', 'MILNER ESTATES PLC.', 'NEWCASTLE UNITED PLC.', 'NORTHAMBER PLC.', 'OLD ENGLISH INNS PLC', 'PHOTOBITION PLC.', 'POWDERJECT PHARMS.PLC.', 'OPD GROUP PLC.', 'QUINTAIN ESTS.& DEV.PLC.', 'ROBERT WALTERS', 'FIDESSA GROUP PLC.', 'SFI GROUP PLC.', 'AXIS-SHIELD PLC.', 'SHL GROUP PLC.', 'PHAROS ENERGY PLC.', 'GAME GROUP PLC.', 'ULTRAFRAME PLC.', 'UNITED OVERSEAS GP. PLC', 'USHERS OF TROWBRIDGE GP.', 'VERSAILLES GROUP PLC.', 'WELLINGTON UNDWRT.PLC.', 'PLANESTATION GROUP PLC.', 'NATIONAL GRID PLC.', 'PROVALIS PLC.', 'ARLA FOODS PLC.', 'MERANT PLC.', 'MONSOON PLC.', 'WH SMITH PLC.', 'ARM HOLDINGS PLC.', 'COMPUTACENTER PLC.', 'GUARDIAN IT PLC', 'COUNTRYWIDE ASSURED PLC.', 'MATALAN PLC.', 'THOMSON TRAVEL GP. PLC', 'EDINBURGH WWD.IT.PLC.', 'MURRAY TMT IT.', 'SELFRIDGES PLC', 'TOROTRAK PLC.', 'WILLIAMS PLC.', 'ALLIED ZURICH PLC', 'COCA-COLA BEVERAGES PLC', 'ITNET PLC.', 'NEW LOOK GROUP PLC.', 'NHP PLC.', 'FAIRVIEW HOLDINGS PLC', 'ABERDEEN JAPAN IT.PLC.', 'SMALLER COS.IT.PLC.', 'TERRANOVA', 'NEX GROUP PLC.', 'ABERDEEN HIGH INCOME PLC', 'ABERDEEN PF.TST.PLC.', 'ACTION PLC.', 'ABDN.EMM.INV.CO.LTD.', 'ATRIUM UNDERWRITING PLC.', 'SIGNATURE REST.PLC.', 'BREWIN DOLPHIN HDG.PLC.', 'GULLANE ENTM. PLC', 'INSTORE PLC.', 'CAMMELL LAIRD HDG. PLC', 'CARE UK PLC.', 'CELTIC PLC.', 'CHARACTER GROUP PLC.', 'CHARLES TAYLOR PLC.', 'CITY MRCH.HIGH YLD.LTD.', 'CLINTON CARDS PLC.', 'COMPCO HOLDINGS PLC.', 'DAWSON HOLDINGS PLC.', 'DCS GROUP PLC.', 'DELANCEY ESTATES PLC.', 'DUD.JENKINS GP.PLC.', 'ECSOFT GROUP PLC', 'ESKMUIR PROPERTIES PLC', 'JPMF.TECH. TRUST PLC', 'COE GROUP PLC.', 'FREEPORT PLC.', 'GAME', 'GOLDSHIELD GROUP PLC.', 'GOSHAWK IN.HDG.PLC.', 'REDDE PLC.', 'HIT ENTERTAINMENT PLC.', 'HITACHI CAPITAL(UK) PLC.', 'INFORMA PLC.', 'ISOTRON PLC.', 'JZ CAPITAL PARTNERS LTD.', 'KS BIOMEDIX HOLDINGS PLC', 'KILN LTD.', 'METROLINE PLC', 'NEWS COMMS. & MEDIA PLC', 'OXF. ASYMMETRY INTL.PLC', 'OXF. GLYCOSCIENCES PLC.', 'PRISM RAIL PLC', 'RPS GROUP PLC.', 'SHERWOOD INTL. PLC', 'NOVAE GROUP PLC.', 'TAYLOR & FRANCIS GP.PLC.', 'TRIAD GROUP PLC.', 'WORKSPACE GROUP PLC.', 'WREN', 'BIOGLAN PHARMA PLC', 'ENERGISER INVS.PLC.', 'BMO PRIV.EQ.TST.PLC.', 'MARTIN CURRIE GLB.PRTF.', 'MURRAY GLB.RTN.TST.PLC', 'SABMILLER PLC.', 'SYNSTAR PLC.', 'ANGLO AMERICAN PLC.', 'CANARY WHARF GROUP PLC.', 'MORSE PLC.', 'CARILLION PLC.', 'EXCHANGE FS GROUP PLC.', 'FUTURE PLC.', 'KCOM GROUP PLC.', 'OLD MUTUAL LIMITED', 'M (2003) PLC.', 'G4S PLC.', 'AIM TRUST IT.PLC.', 'MEDIWATCH PLC.', 'TIMEWEAVE PLC.', 'OPSEC SECURITY GP.PLC.', 'ARENA LEISURE PLC.', 'AUTOLOGIC HOLDINGS PLC.', 'AVESCO GROUP PLC.', 'AXON GROUP PLC.', 'BLLE.GIFF.SHIN NPN.PLC.', 'BALDWINS INDL. SVS. PLC', 'BALTIMORE PLC.', 'BELL GROUP PLC.', 'BLOOMSBURY PBL.PLC.', 'RENSBURG SHEPPARDS PLC.', 'CHARLES STANLEY GP.PLC.', 'CHIME COMMS.PLC.', 'CLUBHAUS PLC.', 'DANA PETROLEUM PLC.', 'DTZ HOLDINGS PLC.', 'DUNEDIN ENTER.IT.PLC.', 'PANMURE GORDON & CO.PLC.', 'EASYNET GROUP PLC.', 'EASYSCREEN PLC.', 'EURO SALES FINANCE PLC.', 'FIBERNET GROUP PLC.', 'FINANCIAL OBJECTS PLC.', 'ALLZ.TECH.TST.PLC.', 'FITNESS FIRST PLC', 'FLEM.INC&CAP.IT.PLC.', 'FRENCH CONNECTN.GP.PLC.', 'MITON INC.OPPS.TST.PLC', 'GARTMORE DS.TRUST PLC.', 'GLOTEL PLC.', 'GYRUS GROUP PLC.', 'HUGHES (TJ) PLC.', 'ICM COMPUTER GROUP PLC.', 'IMS GROUP PLC', 'INCEPTA GROUP PLC.', 'HYVE GROUP PLC.', 'JUPITER ENHANCED IT.PLC.', 'JUP.EUROPEAN IT.PLC.', 'L GARDNER GP. PLC', 'LA FITNESS PLC.', 'MART.CURRIE JAP.IT.PLC.', 'MWB GROUP HOLDINGS PLC.', 'MG PLC', 'MILLER FISHER GROUP PLC', 'NSB RETAIL SYSTEMS PLC.', 'HIGHWAY IN.GROUP PLC.', 'PLANIT HOLDINGS PLC.', 'PLASMON PLC.', 'TRADUS', 'RAGE PLC.', 'PROTAGONA PLC', 'CASTLETON TECH.PLC.', 'RELIANCE SCTY.GP.PLC.', 'SAVILLS PLC.', 'SECOND SCOT.NAT.IT.PLC.', 'SHAW(ARTHUR) & CO PLC', 'SPORTSWORLD MDA.GP.PLC.', 'TED BAKER PLC.', 'TELEVISION CORP.PLC.', 'TERENCE CHAPMAN GP. PLC', 'THOMPSON CLIVE IT.PLC.', 'TOPPS TILES PLC.', 'TOREX GROUP HIRE PLC.', 'UMECO PLC.', 'VEGA GROUP PLC.', 'VOCALIS GROUP PLC.', 'WSP GROUP PLC.', 'WT FOODS PLC.', 'XAAR PLC.', 'REVENUE ASR.SVS.PLC.', 'DE VERE GROUP PLC.', 'ESPORTA PLC', 'C & W COMMS.', 'CAPITAL SHOP.CENTS.PLC.', 'EUROMONEY INSTL.INVR.PLC', 'FREESERVE PLC.', 'INDE.ENERGY HDG.PLC', 'RETAIL DECISIONS PLC.', 'SCIPHER PLC.', 'THUS GROUP PLC.', 'ECKOH PLC.', 'TEAMTALK MEDIA PLC.', 'AMERINDO INET.FUND PLC.', 'BATM ADVANCED COMMS.LTD', 'BOOKHAM TECHNOLOGY PLC.', 'EYRETEL PLC.', 'JPM.JAP.SMCOS.PLC.', 'BSD CROWN LTD.', 'IZODIA PLC.', 'SURFCONTROL PLC.', 'LASTMINUTE.COM PLC.', 'STAFFWARE PLC.', 'WESTON MEDICAL PLC.', 'BIOSCIENCE INV.TST.PLC.', '3I EUR.TECH.TST.PLC.', 'ENERGIS PLC', 'ADVANCED MED.SLTN.GP.PLC', 'HENDERSON HIGH INC.PLC.', 'ACTINIC PLC', 'DIXONS CARPHONE PLC.', 'CLAIMS DIRECT PLC.', 'DIMENSION DATA HDG.PLC.', 'EGG PLC.', 'GRANADA MEDIA PLC.', 'INDIGOVISION GROUP PLC.', 'INNOVATION GROUP PLC.', 'INTEC TELECOM SYS.PLC.', 'IQE PLC.', 'ISOFT GROUP PLC.', 'KNOWLEDGE MANAGEMENT PLC', 'BERKELEY TECHNOLOGY LTD.', 'MDY HEALTHCARE PLC.', 'ORCHESTREAM HDG.PLC.', 'TELECITY PLC.', 'WORKPLACE SYS.INTL.PLC.', 'ZEN RESEARCH PLC', 'BABCOCK INTL.GP.PLC.', 'INNOGY HOLDINGS', 'LATTICE GROUP', 'CARNIVAL PLC.', 'BAILLIE GIFF.JAPAN PLC.', 'CHUBB PLC.', 'KIDDE PLC.', 'APC TECHNOLOGY GP.PLC.', 'AFFINITY INTERNET PLC', 'ALIZYME PLC.', 'ALTERIAN PLC.', 'SAROSSA PLC.', 'ARC INTERNATIONAL PLC.', 'AUTONOMY CORP.LTD.', 'BEESON GREGORY GP.PLC.', 'AVEVA GROUP PLC.', 'CML MICROSYSTEMS PLC.', 'CLNS.STEW.HAWKPOINT PLC.', 'COMMUNISIS PLC.', 'DART GROUP PLC.', 'DATAFLEX HOLDINGS PLC.', 'DECHRA PHARMS.PLC.', 'KOFAX LTD.', 'STAKEHOLDERS MMTM.PLC.', 'HANSA INV.CO.LTD.', 'JPMORGAN SMCOS.IT.PLC.', 'HEALTH CLINIC (THE) PLC.', 'HEND.EUR.MICRO TRUST', 'HIGHBURY HSE.COMMS.PLC.', 'IDS GROUP PLC.', 'XP POWER LTD.', 'IG GROUP PLC.', 'INTERCARE GROUP PLC.', 'INTL.BIOTECHNOLOGY PLC.', 'ITOUCH PLC.', 'JUP.DIV.& GW.PLC.', 'KNOWLEDGE SPT.SY.PLC.', 'SOURCE BIOSCIENCE PLC.', 'BLACKROCK NEW EN.IT.PLC.', 'SCOTTY GROUP PLC.', 'SCHRODER UK MID CAP.FD.', 'MUSIC CHOICE EUROPE PLC.', 'NCIPHER PLC.', 'PRIVATE EQ.INVESTOR PLC.', 'ORBIS PLC.', 'PATSYSTEMS PLC.', 'PEACOCK GROUP PLC.', 'PENNA CONSULTING PLC.', 'PETERHOUSE GP. PLC.', 'PRELUDE TRUST PLC.', 'PROJECT TELECOM PLC.', 'QUARTERLY HIGH INC.PLC.', 'REDBUS INTERHOUSE PLC.', 'IWG PLC', 'ROBERT WALTERS PLC.', 'SANCTUARY GROUP PLC.', 'SDL PLC.', 'SPORTECH PLC.', 'SILENCE THERP.PLC.', 'SAINT DAVIDS IT.', 'SPG MEDIA GROUP PLC.', 'SUPERSCAPE VR PLC.', 'TARSUS GROUP PLC.', 'TELECOM PLUS PLC.', 'TTP COMMUNICATIONS PLC.', 'UNITE GROUP PLC.', 'PORTRAIT SOFTWARE PLC.', 'FCX INTERNATIONAL PLC', 'BRADFORD & BINGLEY PLC.', 'EASYJET PLC.', 'RELIANCE GENEMEDIX PLC.', 'RIVERSOFT PLC.', 'TULLOW OIL PLC.', 'WINCANTON PLC.', 'MARL.STIRLING PLC.', 'PAGEGROUP PLC.', 'PARTHUS TECHNOLOGIES PLC', 'BRAMBLES INDUSTRIES PLC.', 'WOOLWORTHS GROUP PLC.', 'ANTOFAGASTA PLC.', 'FRIENDS PRVT.GROUP PLC.', 'LONDON STOCK EX.GP.PLC.', 'PHS GROUP PLC.', 'O2 PLC.', 'ALKANE ENERGY PLC.', 'AORTECH INTL.PLC.', 'CRANSWICK PLC.', 'FID.SPC.VALUES IT.PLC.', 'GALLIFORD TRY PLC.', 'HERCULES PR.SVS. PLC.', 'INTERNATIONAL EN.GP.PLC.', 'JUPITER EUR.OPPS.', 'JUPITER FINL.TST.', 'KENSINGTON GROUP PLC.', 'LIONTRUST ASSET MAN.PLC.', 'MANAGEMENT CNSL.GP.PLC.', 'MERCHANT RETAIL GP.PLC.', 'OXFORD BIOMEDICA PLC.', 'PALADIN RESOURCES PLC.', 'PERSONAL ASSETS TST.PLC.', 'ROYAL LONDON UK EQUITY', 'VANCO PLC.', 'WHITEHEAD MANN GP.PLC.', 'JPMORGAN MUA.TST.PLC.', 'MINORPLANET SYSTEMS PLC.', 'VENTURE PRODUCTION PLC.', 'XSTRATA PLC.', 'GOVETT STRATEGIC TRUST', 'AQUARIUS PLATINUM LTD.', 'BURBERRY GROUP PLC.', 'HMV GROUP PLC.', 'INTERTEK GROUP PLC.', 'INVESTEC PLC.', 'PUNCH TAVERNS PLC.', 'TRIBAL GROUP PLC.', 'WILLIAM HILL PLC.', 'WOOD GROUP (JOHN) PLC.', 'BEAZLEY PLC.', 'BELHAVEN GROUP PLC.', 'BETT PLC', 'BIG YELLOW GROUP PLC.', 'BURTONWOOD PLC.', 'CLARKET ORD', 'CORIN GROUP PLC.', 'DETICA GROUP PLC.', 'DRES.RCM ENDOW.2003 PLC.', 'DYSON GROUP PLC.', 'EBOOKERS PLC.', 'ENNSTONE PLC.', 'FISHER(JAMES)& SONS PLC.', 'HARDY UNDWRT.BER.LTD.', 'HEND.EUROTR.PLC.', 'IVS.PERP.UK SMCOS.IT.PLC', 'LOOKERS PLC.', 'MICE GROUP PLC.', 'RADSTONE TECHNOLOGY PLC.', 'RICHMOND FOODS PLC.', 'SCS UPHOLSTERY PLC.', 'XENOVA GROUP PLC.', 'ICTL.HOTELS GROUP PLC.', 'MITCHELLS & BUTLERS PLC.', 'DARTY PLC.', 'BENFIELD GROUP LTD.', 'EVOLUTION GROUP PLC.', 'INCISIVE MEDIA PLC.', 'TELENT PLC.', 'BARRICK GD.(HDG.) LTD.', 'HIBU PLC.', 'BARING EMERGING EU.PLC.', 'CHAUCER HOLDINGS PLC.', 'DATAMONITOR PLC.', 'BIONOSTICS PLC.', 'GARTMORE IRISH GW.FD.PLC', 'HORNBY PLC.', 'JPMORGAN RUSSIAN PLC', 'MOUCHEL GROUP PLC.', 'NORD ANGLIA ED.PLC.', 'NTH.ATL.SMCOS.IT.PLC.', 'NORTHUMBRIAN WT.GP.PLC.', 'OTTAKARS PLC.', 'PATIENTLINE PLC.', 'ROK PLC.', 'UIL LIMITED', 'VP PLC.', 'WOLFSON MICROELS.PLC.', 'ALEA GP.HDG.(BERMUDA)LTD', 'BURREN ENERGY PLC.', 'JN.HEND.GP.PLC.', 'VEDANTA RESOURCES LTD.', 'SOUTH STAFFORDSHIRE PLC.', 'CHESNARA PLC.', 'COUNTRYWIDE PLC.', 'PREMIER VTNR.GP.PLC', 'CATLIN GROUP LTD.', 'CSR PLC.', 'DIGNITY PLC.', 'CLARKSON PLC.', 'E2V TECHNOLOGIES PLC.', 'EUROCASTLE INV.LTD.', 'HALFORDS GROUP PLC.', 'SCHRODER RLST.IT.LTD.', 'BLACKROCK GTR.EU.IT.PLC.', 'PINEWOOD GROUP PLC.', 'PREMIER FOODS PLC.', 'SONDEX PLC.', 'UMBRO PLC.', 'VIRGIN MOBILE HDG.PLC.', 'DX SERVICES PLC.', 'ACTIVE CAPITAL TRUST PLC', 'ADMIRAL GROUP PLC.', 'ANGLO PACIFIC GROUP PLC.', 'BRAEMAR SHIP.SVS.PLC.', 'CAFFE NERO GROUP PLC.', 'CAMELLIA PLC.', 'EDINBURGH OIL & GAS PLC.', 'ENTERPRISE PLC.', 'ERINACEOUS PLC.', 'HG CAPITAL TRUST PLC.', 'INVESCO PR.INC.TST.', 'JESSOPS PLC.', 'LAMBERT HOWARTH GP.PLC.', 'MCKAY SECURITIES PLC.', 'MELROSE RESOURCES PLC.', 'OFFICE2OFFICE PLC.', 'PAYPOINT PLC.', 'SHORE CAP.GP.(GSY.)PLC.', 'WYG PLC.', 'ARMORGROUP INTL.PLC.', 'CENTAUR MEDIA PLC.', 'INION OY', 'PD PORTS PLC.', 'PHOENIX IT GROUP PLC.', 'RAYMARINE PLC.', 'BIOME TECHNOLOGIES PLC', 'HUNTSWORTH PLC.', 'CARTER & CARTER GP.PLC', 'CTR.PARCS (UK) GP.PLC.', 'ENTERTAINMENT RTS.PLC.', 'BMO COML.PTU.LTD.', 'ESSENTRA PLC.', 'IG GROUP HOLDINGS PLC.', 'ROYAL DUTCH SHELL', 'AGCERT INTL.PLC.', 'FOSECO PLC.', 'INMARSAT PLC.', 'MAPELEY LTD.', 'MICRO FOCUS INTL.PLC.', 'BWIN PARTY DIG.ENTM.PLC.', 'PROSTRAKAN GROUP PLC.', 'RHM PLC.', 'SCHDR.ORNTL.INC.FD.LTD.', 'ANGLO-EASTERN PLTNS.PLC.', 'AXA PROPERTY TRUST PLC.', 'EMERALD ENERGY PLC.', 'GONDOLA HOLDINGS PLC.', 'HIKMA PHARMS.PLC.', 'HYDER CONSULTING PLC.', 'PICTON PROPERTY INC.LTD.', 'KAZ MINERALS PLC.', 'LAND OF LEATHER HDG.PLC.', 'LDN.& ASSOCS.PROPS.PLC.', 'NEW STAR IT.PLC', 'PETROFAC LTD.', 'PRIMARY HLTH.PROPS.PLC.', 'STD.LF.PRIV.EQ.PLC', 'ADVANTAGE PR.INC.TST.LTD', '888 HOLDINGS PLC.', 'CENTURION ELTN.PLC.', 'HERMES PACIFIC INVS.PLC.', 'FORESIGHT 4 VCT PLC.', 'GENESIS PTL.CORP.PLC.', 'HARROGATE GROUP PLC.', 'IP GROUP PLC.', 'SECURITY RESH.GP.PLC.', 'FUN TECHNOLOGIES INC', 'ALPHA PYRENEES TST.LTD.', 'ALT.INV.STGIS.LTD.', 'BRITVIC PLC.', 'DEXION ABSOLUTE LTD.', 'DEXION EQUITY ALT.LTD.', 'DRAX GROUP PLC.', 'BLACKROCK EMRG.EUROPE', 'IMPAX ENV.MKTS.PLC.', 'BMO RESINV.LTD.', 'MELROSE INDUSTRIES LTD.', 'MORANT WRIGHT JAPAN PLC.', 'PRODESSE INVESTMENT LTD.', 'REAL ESTATE CR.INVS.LTD', 'STD.LF.INV.PR.INC.LTD.', 'STHREE PLC.', 'TRIBUNE UK TRACKER PLC.', 'UK BALANCED PR.TST.LTD.', 'GOLDENPORT HDG.INCO.', 'HICL INFRASTRUCTURE PLC.', 'BLACKROCK LNAMER.IT.PLC.', 'OPTOS PLC.', 'QINETIQ GROUP PLC.', 'INSPIRED CAPITAL PLC.', 'RIGHTMOVE PLC.', 'SCOTT WILSON GROUP PLC.', 'CLINPHONE PLC.', 'GOLDMAN SACHS DYM.LTD.', 'GOLDMAN SACHS DYM.OPPS.', 'STHN.CROSS HLTHCR.GP.PLC', 'STD.LF.ABDN.PLC.', 'STOBART GROUP LTD.', 'BIFFA PLC.', 'EXPERIAN PLC.', 'FIBERWEB PLC.', 'ABDN.ASIAN INC.FUND LTD.', 'ABERDEEN STD.AI.FCS.PLC.', 'ACCIDENT EX.GP.PLC.', 'ASHMORE GROUP PLC.', 'ASSURA PLC.', 'CMA GLB.HEDGE PCC LTD.', 'CONNAUGHT PLC.', 'CRESTON PLC.', 'DEXION COMMODITIES LTD.', 'DUNELM GROUP PLC.', 'TROY INCOME & GW.TST PLC', 'HOCHSCHILD MINING PLC.', 'SCHRODER GLB.RLST.LTD.', 'ISIS PROPERTY TRUST', 'TAMAR EUR.INDL.FUND LTD.', 'LATCHWAYS PLC.', 'MONTANARO UK SMCOS.PLC.', 'REALM THERAPEUTICS PLC.', 'REA HOLDINGS PLC.', 'REAL ESTATE OPPS.PLC.', 'STYLES & WOOD GROUP PLC.', 'TEESLAND PLC.', 'TP ICAP PLC.', 'UK COML.PR.REIT LTD.', 'PEBBLE BEACH SYS.GP.PLC', 'BLUEBAY ASSET MAN.PLC.', 'INVISTA EUR.RLST.TST.', 'LSL PROPERTY SVS.PLC.', 'SALAMANDER ENERGY PLC.', 'CINEWORLD GROUP PLC.', 'LOCAL SHOP.REIT PLC', 'SAFESTORE HOLDINGS PLC.', 'SPORTS DIRECT INTL.PLC.', 'WELLSTREAM HOLDINGS PLC.', 'XCHANGING PLC.', 'INTL.PSNL.FINANCE PLC.', 'MONDI PLC.', 'EAGA PLC.', 'FERREXPO PLC.', 'GEM DIAMONDS LTD.', 'HARGREAVES LANSDOWN PLC.', 'IMP.ENERGY CORP.PLC.', 'MONEYSUPERMARKET COM GP.', 'NEW STAR ASTMGMT.GP.PLC.', 'PV CRYSTALOX SOLAR PLC.', 'SEPURA PLC.', 'SUPERGLASS HOLDINGS PLC.', 'AHTIUM OYJ', 'VECTURA GROUP PLC.', '3I INFRASTRUCTURE PLC.', 'AIR PARTNER PLC.', 'ARICOM PLC.', 'CENTRAL RAND GOLD LTD.', 'CQS NATRES.GW.&.INC.PLC.', 'GENUS PLC.', 'GLOBEOP FINANCIAL SVS.SA', 'HANSARD GLOBAL PLC.', 'HILTON FOOD GROUP PLC.', 'INTL.FERRO METALS LTD.', 'JPMORGAN CHINESE PLC.', 'BLACKR.EN.&.RES.INU.PLC.', 'NCC GROUP PLC.', 'PACIFIC HORIZON IT.PLC.', 'PRINCIPLE CAPITAL IT.PLC', 'TAPESTRY INV.CO.PCC LTD.', 'TELECITY GROUP PLC.', '3I QUOTED PRIV.EQ.PLC.', 'ABSOLUTE RETURN TST.LTD.', 'INTERNATIONAL PBPART.LTD', 'EURASIAN NATRES.CORP.PLC', 'NAMAKWA DIAMONDS LTD.', 'RDI REIT PLC.', 'BH MACRO LTD.', 'BLACKROCK ABST.RTN.', 'DEXION TRADING LTD.', 'DOMINOS PIZZA GROUP PLC', 'HERITAGE OIL PLC.', 'MECOM GROUP PLC.', 'THAMES RVR.MLT.HED.PLC', 'BH GLOBAL LTD.', 'HIGHBRIDGE TAC.CR.FD.LTD', 'CADOGAN PETROLEUM PLC.', 'FRESNILLO PLC.', 'MEARS GROUP PLC.', 'SPICE PLC.', 'SYNERGY HEALTH PLC.', 'ARTEMIS ALPHA TRUST PLC', 'GOODWIN PLC.', 'LAMPRELL PLC.', 'MEDICX FUND LTD.', 'MW TOPS LTD.', 'THE SCOT.ORNTL.SMCOS.PLC', 'PETROPAVLOVSK PLC.', 'ECOFIN WTPWR.OPPS.PLC.', 'LANCASHIRE HOLDINGS LTD.', 'FRIENDS LIFE GROUP LTD.', 'BOOKER GROUP PLC.', 'GENESIS EMRG.MKTS.FD.LTD', 'IMPAX ASIAN ENV.MKTS.PLC', 'LMS CAPITAL PLC.', 'AFREN PLC.', 'CABLE & WRLS.WWD.PLC.', 'GARTMORE GROUP LTD.', 'HANSEN TNSMS.INTL.NV', 'HANSTEEN HOLDINGS PLC.', 'TALKTALK TELECOM GP.PLC.', 'ENQUEST PLC.', 'CAP.& CNTS.PROPS.PLC.', 'ACACIA MINING PLC.', 'THE BIOTECH GROWTH PLC.', 'CAZENOVE ABST.EQ.LTD.', 'CENTAMIN PLC.', 'CPPGROUP PLC.', 'ESSAR ENERGY PLC.', 'FIDELITY CHIN.SPSTN.PLC.', 'MANCHESTER & LDN.IT.PLC.', 'METRIC PR.INVS.PLC.', 'ABERDEEN NEW IDA.IT.PLC.', 'PROMETHEAN WORLD PLC.', 'SUPERDRY PLC.', 'EXILLON ENERGY PLC.', 'JPMORGAN GLB.EMM.INU.PLC', 'JUPITER FUND MAN.PLC.', 'KENMARE RESOURCES PLC.', 'OCADO GROUP PLC.', 'PHNX.GHG.PLC.', 'PLR.CAP.GLB.HLTHCR.TST.', 'RAVEN PR.GP.LTD.', 'RSM TENON GROUP PLC.', 'RUFFER INV.COMP.RED.PTG.', 'SPORTINGBET PLC.', 'ACENCIA DEBT STGIS.LTD.', 'AZ ELECTRONIC MATS.SA', 'BETFAIR GROUP PLC.', 'CITY OF LDN.INV.GP.PLC.', 'LONDONMETRIC PR.PLC.', 'SINCLAIR IS PHARMA PLC.', 'INTL.CONS.AIRL.GROUP SA', 'ANGLESEY MINING PLC.', 'FLYBE GROUP PLC.', 'JOHN LAING INFR.FD.LTD.', 'GLENCORE PLC', 'BLACKR.FTS.IT.PLC.', 'CAPITAL GEARING TST.PLC.', 'CARRS GROUP PLC.', 'EP GLOBAL OPPS.TRUST', 'HENDERSON DIVR.INC.PLC.', 'MIDDLEFIELD CDN.INC.PCC', 'NB GLOBAL FR.INC.FD.PLC.', 'NEW WORLD RESOURCES PLC.', 'PERFORM GROUP PLC.', 'SPIRIT PUB COMPANY PLC.', 'ALLIED GOLD MINING PLC.', 'KENTZ CORPORATION LTD.', 'OPHIR ENERGY PLC.', 'ASHMORE GLOBAL OPPS.LTD.', 'ASIA RESOURCE MRLS.PLC.', 'CRH PLC.', 'EVRAZ PLC.', 'POLYMETAL INTL.PLC.', 'UTILICO EMM.TST.PLC', 'AVOCET MINING PLC.', 'BILFINGER BERGER GLB.PLC', 'GREENCORE GROUP PLC.', 'PETRA DIAMONDS LTD.', 'RUSPETRO PLC.', 'BANK OF GEORGIA GP. PLC.', 'BLUECREST BLUETREND LTD.', 'GCP INFR.INVS.LTD.', 'JUPITER SPL.IT.PLC.', 'NMC HEALTH PLC.', 'S & U PLC.', 'PLAYTECH PLC.', 'ALENT PLC.', 'SYNCONA LIMITED', 'DIRECT LINE IN.GP.PLC.', 'UDG HEALTHCARE PUB.LTD.', 'ABERDEEN NEW THAI IT.PLC', 'ICG-LONGBOW SEN.SECD.PLC', 'STARWOOD EUR.RLST.PLC.', 'DW CATALYST FUND LTD.', 'BLACKR.NA.INC.IT.PLC.', 'CREST NICHOLSON HDG.PLC.', 'DCC PLC.', 'DIVERSE INC.TST.(THE)PLC', 'ESURE GROUP PLC.', 'GREENCOAT UK WIND PLC.', 'HELLERMANNTYTON GP.PLC.', 'MONTANARO EUR.SMCOS.PLC.', 'TWENTYFOUR INCOME PLC.', 'MEDICLINIC INTL.PLC.', 'BLUEFIELD SOLAR INC.PLC.', 'CARACAL ENERGY INC.', 'COCA COLA HBC AG', 'CVC CR.PTNS.EUR.OPPS.PLC', 'ENTERTAINMENT ONE LTD.', 'JPMORGAN GLB.CVS.PLC.', 'PTSHP.ASSURANCE GP.PLC', 'POLAR CAP.GLB.FINLS.PLC.', 'THE RENEWS.INFR.GP.LTD.', 'TYMAN PLC.', 'ARROW GLOBAL GROUP PLC.', 'FORESIGHT SOLAR FD.LTD.', 'FOXTONS GROUP PLC.', 'GRAFTON GROUP UTS.PLC.', 'MERLIN ENTMT.PLC.', 'RIVERSTONE ENERGY PLC', 'ROYAL MAIL PLC.', 'STOCK SPIRITS GROUP PLC.', 'INFINIS ENERGY PLC.', 'JRP GROUP PLC.', 'CQS NEW CTY.HIY.FD.LTD.', 'SERVELEC GROUP PLC.', 'ABERFORTH SPL.INC.PLC.', 'ALCENTRA EUR.FIF.PLC.', 'AO WORLD PLC.', 'BRIT PLC.', 'CAMBIAN GROUP PLC.', 'CIRCASSIA PHARMS.PLC.', 'CUSTODIAN REIT PLC', 'EXOVA GROUP PLC.', 'GULF MARINE SVS.PLC.', 'JLEN ENV.ASS.GP.LTD.', 'JUST EAT PLC', 'KENNEDY WLSN.EU.RLST.PLC', 'MACAU PR.OPPOR.FUND LTD.', 'MCCOLLS RETAIL GP.PLC', 'MOUNTVIEW ESTATES PLC.', 'PETS AT HOME GROUP PLC.', 'POLYPIPE GROUP PLC.', 'POUNDLAND GROUP PLC.', 'TWENTYFOUR ASSET PLC.', 'ALLIED MINDS PLC.', 'CARD FACTORY PLC', 'FDM GROUP PLC.', 'FUNDSMITH EMERGING PLC.', 'GAME DIGITAL PLC.', 'NOSTRUM OIL & GAS PLC.', 'ONESAVINGS BANK PLC.', 'POLLEN STR.SECD.LEND.PLC', 'SAGA PLC.', 'SPIRE HEALTHCARE GP.PLC.', 'SQN ASSET FIN.INC.FD.LTD', 'SSP GROUP PLC.', 'TRITAX BIG BOX REIT PLC.', 'TSB BANKING GROUP PLC.', 'VOLUTION GROUP PLC.', 'ZPG PLC.', 'INDIVIOR PLC.', 'JIMMY CHOO', 'NEXTENERGY SOLAR FD.LTD.', 'TUI AG', 'AA PLC.', 'VIRGIN MONEY HLDG.PLC.', 'ALDERMORE GROUP PLC.', 'AUTO TRADER GROUP PLC.', 'B&M EUR.VAL.RET.PLC.', 'DFS FURNITURE PLC', 'EMPIRIC STUDENT PR.PLC', 'ENERGY ASSETS GROUP PLC.', 'HSS HIRE GROUP PLC.', 'JOHN LAING GROUP PLC.', 'SURESERVE GROUP PLC.', 'NANOCO GROUP PLC.', 'RDL REALISATION PLC.', 'SANNE GROUP PLC.', 'SEQUOIA ECON.INFR.PLC.', 'SHAWBROOK GROUP PLC', 'STRATEGIC EQUITY CAP.PLC', 'VPC SPY.LENDING INVS.PLC', 'WIZZ AIR HOLDINGS PLC.', 'WOODFORD PTNT.CAP.PLC.', 'KAINOS GROUP PLC.', 'PURETECH HEALTH PLC.', 'SOPHOS GROUP PLC', 'EQUINITI GROUP PLC.', 'HARBOURVEST GLOBAL', 'HASTINGS GROUP HDG.LTD.', 'HOSTELWORLD GROUP PLC.', 'WORLDPAY GROUP PLC.', 'FLUTTER ENTM.PLC.', 'GEORGIA HLTHCR.GP.PLC.', 'MCCARTHY AND STONE PLC.', 'PAYSAFE GROUP LTD.', 'REGIONAL REIT LIMITED', 'SOFTCAT PLC.', 'THE GYM GROUP PLC.', 'ASCENTIAL PLC.', 'CMC MARKETS PLC.', 'CYBG PLC.', 'EDISTON PR.INV.CO.PLC.', 'FORTERRA PLC.', 'SME CR.RLSATN.FD.LTD.', 'HENDERSON INTL.INU.PLC.', 'THE INDEPENDENT IT.PLC.', 'LINDSELL TRAIN', 'METRO BANK PLC.', 'ON THE BEACH GROUP PLC.', 'PHOENIX SPREE DTL.LTD.', 'GCP ASST.BACKED INFD.LTD', 'SCHDR.EUR.REIT.TST.PLC.', 'SMURFIT KAPPA GROUP PLC.', 'TAR.HLTHCR.REIT PLC.', 'VINACAPITAL VTM.OPF.LTD.', 'ECOFIN GLB.UTILS.&.INFR.', 'GVC HOLDINGS PLC.', 'MOTORPOINT GROUP PLC.', 'VIETNAM ENTER.INVLD.', 'GOCO GROUP PLC.', 'CONVATEC GROUP PLC.', 'GCP STUDENT LIVING PLC.', 'HOLLYWOOD BOWL GP.PLC.', 'LUCECO PLC.', 'NEWRIVER REIT LTD.', 'TBC BANK GROUP PLC.', 'CIVITAS SOCIAL HSG.PLC.', 'BB HEALTHCARE TRUST PLC.', 'CLIPPER LOGISTICS PLC.', 'LXI REIT PLC.', 'MEDICA GROUP PLC.', 'NB PRIVATE EQ.PTNS.LTD.', 'PERSHING SQUARE HDG.LTD.', 'SIRIUS MINERALS PLC.', 'TREATT PLC.', 'UP GLOBAL SOURCING PLC.', 'XPS PENSIONS GROUP PLC.', 'ALFA FINL.SFTW.HLDG.PLC.', 'APAX GLOBAL ALPHA LTD.', 'DP EURASIA N V WI PLC.', 'PURECIRCLE LTD.', 'SIRIUS REAL ESTATE LTD.', 'BCA MARKETPLACE PLC.', 'CHARTER COURT FINANCIAL', 'PRINCESS PRIVATE', 'RHI MAGNESITA ', 'TI FLUID SYSTEMS ', 'ABDN.STD.EUR.LOGIST.INC. ', 'BAKKAVOR GROUP ', 'CONTOURGLOBAL ', 'SABRE INSURANCE ', 'GEORGIA CAPITAL ', 'BAILLIE GIFF.US GW.TST. ', 'CC JAPAN I&G.TST. ', 'ENERGEAN OIL & GAS ', 'INTEGRAFIN HOLDINGS ', 'JTC GROUP ', 'MID WYND INTL.IT. ', 'PALACE CAPITAL ', 'QUILTER ', 'RESIDENTIAL SCR.INC. ', 'RIVER AND MERCANTILE GP. ', 'TEN ENTM.GROUP ', 'TRIPLE PNT.SCL.HSG.REITS ', 'AMIGO HOLDINGS ', 'ASA INTERNATIONAL GROUP ', 'AVAST ', 'GAMESYS GROUP ', 'PLUS500 ', 'VIVO ENERGY ', 'ASTON MARTIN LAGONDA GLOBAL HOLDINGS ', 'FUNDING CIRCLE HOLDINGS ', 'SMITHSON IT. ', 'THIRD PNT.OFFS. (LON) INVRS.£ ']

# %% [markdown]
# ### Read data from Excel

# %%
# # Declare variables
# p = pd.read_excel(relativeLocation, header=None, names=companyNames, index_col=0, sheet_name='p')
# ey = pd.read_excel(relativeLocation, header=None, names=companyNames, index_col=0, sheet_name='ey')
# fcfy = pd.read_excel(relativeLocation, header=None, names=companyNames, index_col=0, sheet_name='fcfy')
# eps = pd.read_excel(relativeLocation, header=None, names=companyNames, index_col=0, sheet_name='eps')
# ptbv = pd.read_excel(relativeLocation, header=None, names=companyNames, index_col=0, sheet_name='ptbv')
# dy = pd.read_excel(relativeLocation, header=None, names=companyNames, index_col=0, sheet_name='dy')
# mv = pd.read_excel(relativeLocation, header=None, names=companyNames, index_col=0, sheet_name='mv')

# for i in fields:
#     i.drop(i.index[0], axis=0, inplace=True)


# Requires file to be open, but is SO MUCH FASTER
p = pd.DataFrame(xw.books(fileName[1:]).sheets("p").range("A1:BVI287").value)
ey = pd.DataFrame(xw.books(fileName[1:]).sheets("ey").range("A1:BVI287").value)
fcfy = pd.DataFrame(xw.books(fileName[1:]).sheets("fcfy").range("A1:BVI287").value)
eps = pd.DataFrame(xw.books(fileName[1:]).sheets("eps").range("A1:BVI287").value)
ptbv = pd.DataFrame(xw.books(fileName[1:]).sheets("ptbv").range("A1:BVI287").value)
dy = pd.DataFrame(xw.books(fileName[1:]).sheets("dy").range("A1:BVI287").value)
mv = pd.DataFrame(xw.books(fileName[1:]).sheets("mv").range("A1:BVI287").value)

fields = [p, ey, fcfy, eps, ptbv, dy, mv]

# Clean up the dataframes to have correct cols and rows
for field in fields:
    field.columns = companyNames
    field.index = field[field.columns[0]]
    del field[field.columns[0]]
    field.drop(field.index[0], inplace=True)
    field.replace("NA", np.nan, inplace=True)
    field = field.apply(pd.to_numeric,errors='coerce')

# %%
# Return
r = p/p.shift(1)-1

# Moving averages (for momentum)
p_ma2 = p.rolling(window=2).mean()
p_ma3 = p.rolling(window=3).mean()
p_ma6 = p.rolling(window=6).mean()
p_ma12 = p.rolling(window=12).mean()
p_ma18 = p.rolling(window=18).mean()
